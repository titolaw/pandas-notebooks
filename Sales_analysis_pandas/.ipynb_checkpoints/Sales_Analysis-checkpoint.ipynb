# %% [markdown]
# ### Sales Analysis

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# #### Merging 12 months os sales data into a single file

# %%
# option 1:
files = [file for file in os.listdir('./Sales_Data')]

all_months_data = pd.DataFrame()

for file in files:
    temp = pd.read_csv("./Sales_Data/"+file)
    all_months_data = pd.concat([all_months_data, temp])
    
all_months_data.to_csv("all_data.csv", index=False)

df = pd.read_csv("all_data.csv")
df

# %%
# option 2
frames = [pd.read_csv('./Sales_Data/Sales_January_2019.csv'), 
          pd.read_csv('./Sales_Data/Sales_February_2019.csv'),
          pd.read_csv('./Sales_Data/Sales_March_2019.csv'),
          pd.read_csv('./Sales_Data/Sales_April_2019.csv'),
          pd.read_csv('./Sales_Data/Sales_May_2019.csv'),
          pd.read_csv('./Sales_Data/Sales_June_2019.csv'),
          pd.read_csv('./Sales_Data/Sales_July_2019.csv'),
          pd.read_csv('./Sales_Data/Sales_August_2019.csv'),
          pd.read_csv('./Sales_Data/Sales_September_2019.csv'),
          pd.read_csv('./Sales_Data/Sales_October_2019.csv'),
          pd.read_csv('./Sales_Data/Sales_November_2019.csv'),
          pd.read_csv('./Sales_Data/Sales_December_2019.csv')]

df = pd.concat(frames,ignore_index=True)
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        141234                      iPhone                1        700
# 1        141235    Lightning Charging Cable                1      14.95
# 2        141236            Wired Headphones                2      11.99
# 3        141237            27in FHD Monitor                1     149.99
# 4        141238            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   319666    Lightning Charging Cable                1      14.95
# 186846   319667       AA Batteries (4-pack)                2       3.84
# 186847   319668             Vareebadd Phone                1        400
# 186848   319669            Wired Headphones                1      11.99
# 186849   319670  Bose SoundSport Headphones                1      99.99
#
#             Order Date                        Purchase Address
# ...

# %% [markdown]
# #### Data cleaning

# %%
# drop NaN rows
nan_df = df[df.isna().any(axis=1)]
nan_df.head()
df = df.dropna(how = 'all')
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        141234                      iPhone                1        700
# 1        141235    Lightning Charging Cable                1      14.95
# 2        141236            Wired Headphones                2      11.99
# 3        141237            27in FHD Monitor                1     149.99
# 4        141238            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   319666    Lightning Charging Cable                1      14.95
# 186846   319667       AA Batteries (4-pack)                2       3.84
# 186847   319668             Vareebadd Phone                1        400
# 186848   319669            Wired Headphones                1      11.99
# 186849   319670  Bose SoundSport Headphones                1      99.99
#
#             Order Date                        Purchase Address
# ...

# %% [markdown]
# #### Find 'Or' and delete it

# %%
df = df[df['Order Date'].str[0:2] != 'Or']
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        141234                      iPhone                1        700
# 1        141235    Lightning Charging Cable                1      14.95
# 2        141236            Wired Headphones                2      11.99
# 3        141237            27in FHD Monitor                1     149.99
# 4        141238            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   319666    Lightning Charging Cable                1      14.95
# 186846   319667       AA Batteries (4-pack)                2       3.84
# 186847   319668             Vareebadd Phone                1        400
# 186848   319669            Wired Headphones                1      11.99
# 186849   319670  Bose SoundSport Headphones                1      99.99
#
#             Order Date                        Purchase Address
# ...

# %% [markdown]
# #### Convert columns to the correct type

# %%
# option 1
df['Quantity Ordered'] = df['Quantity Ordered'].astype('int64')
df['Price Each'] = df['Price Each'].astype('float64')

# %%
# option 2
df['Quantity Ordered'] = pd.to_numeric(df['Quantity Ordered'])
df['Price Each'] = pd.to_numeric(df['Price Each'])

# %%
df.dtypes
# Out:
# Order ID             object
# Product              object
# Quantity Ordered      int64
# Price Each          float64
# Order Date           object
# Purchase Address     object
# dtype: object

# %% [markdown]
# #### Augment data with additional columns

# %% [markdown]
# #### Task 2: Add month column

# %%
df['Month'] = df['Order Date'].str[0:2]
df['Month'] = df['Month'].astype('int32')

# %% [markdown]
# #### Task 3: Add sales column

# %%
df['Sales'] = df['Quantity Ordered'] * df['Price Each']
df.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
# 2   141236          Wired Headphones                 2       11.99
# 3   141237          27in FHD Monitor                 1      149.99
# 4   141238          Wired Headphones                 1       11.99
#
#        Order Date                       Purchase Address  Month   Sales
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215      1  700.00
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035      1   14.95
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016      1   23.98
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001      1  149.99
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301      1   11.99

# %% [markdown]
# #### Task 4: Add a city column

# %%
# Using .apply()
def get_city(address):
    return address.split(',')[1]

def get_state(address):
    return address.split(',')[2].split(' ')[1]

df['City'] = df['Purchase Address'].apply(lambda x: f"{get_city(x)} ({get_state(x)})")

df.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
# 2   141236          Wired Headphones                 2       11.99
# 3   141237          27in FHD Monitor                 1      149.99
# 4   141238          Wired Headphones                 1       11.99
#
#        Order Date                       Purchase Address  Month   Sales  \
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215      1  700.00
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035      1   14.95
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016      1   23.98
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001      1  149.99
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301      1   11.99
#
#                   City
# 0          Boston (MA)
# 1        Portland (OR)
# 2   San Francisco (CA)
# 3     Los Angeles (CA)
# ...

# %% [markdown]
# #### Q1: what was the best month for sales? How much was earned that month?

# %%
results = df.groupby('Month').sum()
results
# Out:
#        Quantity Ordered  Price Each       Sales
# Month
# 1                 10903  1811768.38  1822256.73
# 2                 13449  2188884.72  2202022.42
# 3                 17005  2791207.83  2807100.38
# 4                 20558  3367671.02  3390670.24
# 5                 18667  3135125.13  3152606.75
# 6                 15253  2562025.61  2577802.26
# 7                 16072  2632539.56  2647775.76
# 8                 13448  2230345.42  2244467.88
# 9                 13109  2084992.09  2097560.13
# 10                22703  3715554.83  3736726.88
# 11                19798  3180600.68  3199603.20
# 12                28114  4588415.41  4613443.34

# %%
months = range(1,13)

plt.bar(months,results['Sales'])
plt.xticks(months)
plt.ylabel('Sales in USD (US$)')
plt.xlabel('Month number')
plt.show()

# %% [markdown]
# #### Q2: What city had the highest number of sales?

# %%
results = df.groupby('City').sum()
results
# Out:
#                      Quantity Ordered  Price Each   Month       Sales
# City
#  Atlanta (GA)                   16602  2779908.20  104794  2795498.58
#  Austin (TX)                    11153  1809873.61   69829  1819581.75
#  Boston (MA)                    22528  3637409.77  141112  3661642.01
#  Dallas (TX)                    16730  2752627.82  104620  2767975.40
#  Los Angeles (CA)               33289  5421435.23  208325  5452570.80
#  New York City (NY)             27932  4635370.83  175741  4664317.43
#  Portland (ME)                   2750   447189.25   17144   449758.27
#  Portland (OR)                  11303  1860558.22   70621  1870732.34
#  San Francisco (CA)             50239  8211461.74  315520  8262203.91
#  Seattle (WA)                   16553  2733296.01  104941  2747755.48

# %%
cities = [city for city, df in df.groupby('City')]

plt.bar(cities,results['Sales'])
plt.xticks(cities, rotation = 'vertical',size=8)
plt.ylabel('Sales in USD (US$)')
plt.xlabel('City name')
plt.show()

# %% [markdown]
# #### Q3: What time should we display advertisements to maximize likelihood of customer's buying product?

# %%
# converting Order Date to datetime object
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
df['Hour'] = df['Order Date'].dt.hour
df['Minute'] = df['Order Date'].dt.minute
df.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
# 2   141236          Wired Headphones                 2       11.99
# 3   141237          27in FHD Monitor                 1      149.99
# 4   141238          Wired Headphones                 1       11.99
#
#            Order Date                       Purchase Address  Month   Sales  \
# 0 2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215      1  700.00
# 1 2019-01-28 14:15:00       185 Maple St, Portland, OR 97035      1   14.95
# 2 2019-01-17 13:33:00  538 Adams St, San Francisco, CA 94016      1   23.98
# 3 2019-01-05 20:33:00     738 10th St, Los Angeles, CA 90001      1  149.99
# 4 2019-01-25 11:59:00          387 10th St, Austin, TX 73301      1   11.99
#
#                   City  Hour  Minute
# 0          Boston (MA)    21      25
# ...

# %%
# hours = [hour for hour, df in df.groupby('Hour')]

# plt.plot(hours, df.groupby(['Hour']).count())
# plt.show()

# %% [markdown]
# #### Q4: What products are most often sold together?

# %%
sub_df = df[df['Order ID'].duplicated(keep=False)]

sub_df['Grouped'] = sub_df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))

sub_df = sub_df[['Order ID', 'Grouped']].drop_duplicates()
sub_df.head()
# Out:
#     Order ID                                         Grouped
# 41    141275           USB-C Charging Cable,Wired Headphones
# 57    141290  Apple Airpods Headphones,AA Batteries (4-pack)
# 133   141365                Vareebadd Phone,Wired Headphones
# 153   141384               Google Phone,USB-C Charging Cable
# 220   141450         Google Phone,Bose SoundSport Headphones

# %%
# reference: https://stackoverflow.com/questions/52195887/counting-unique-pairs-of-numbers-into-a-python-dictionary
from itertools import combinations
from collections import Counter

count = Counter()

for row in sub_df['Grouped']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list, 2)))
    
for key, value in count.most_common(10):
    print(key,value)
# Out:
# ('iPhone', 'Lightning Charging Cable') 1005
# ('Google Phone', 'USB-C Charging Cable') 987
# ('iPhone', 'Wired Headphones') 447
# ('Google Phone', 'Wired Headphones') 414
# ('Vareebadd Phone', 'USB-C Charging Cable') 361
# ('iPhone', 'Apple Airpods Headphones') 360
# ('Google Phone', 'Bose SoundSport Headphones') 220
# ('USB-C Charging Cable', 'Wired Headphones') 160
# ('Vareebadd Phone', 'Wired Headphones') 143
# ('Lightning Charging Cable', 'Wired Headphones') 92

# %% [markdown]
# #### Q5: What product sold the most? Why it sold the most?

# %%
prod_group = df.groupby('Product')
quantity_ordered = prod_group.sum()['Quantity Ordered']

products = [product for product, df in prod_group]

plt.bar(products, quantity_ordered)
plt.ylabel('Quantity ordered')
plt.xlabel('Product')
plt.xticks(products, rotation='vertical',size=8)
plt.show()

# %%
# Referece: https://stackoverflow.com/questions/14762181/adding-a-y-axis-label-to-secondary-y-axis-in-matplotlib
prices = df.groupby('Product').mean()['Price Each']

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.bar(products, quantity_ordered, color='g')
ax2.plot(products, prices, color='b')

ax1.set_xlabel('Product Name')
ax1.set_ylabel('Quantity Ordered', color='g')
ax2.set_ylabel('Price ($)', color='b')
ax1.set_xticklabels(products, rotation='vertical', size=8)

fig.show()
# Out:
# /tmp/ipykernel_5136/1736179459.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(products, rotation='vertical', size=8)
# /tmp/ipykernel_5136/1736179459.py:15: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
